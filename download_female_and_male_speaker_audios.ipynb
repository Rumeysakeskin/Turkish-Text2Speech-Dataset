# %% [markdown]
# <a href="https://colab.research.google.com/github/Rumeysakeskin/Turkish-Text2Speech-Dataset/blob/main/download_female_and_male_speaker_audios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install libsox-fmt-all
# !pip install install sox
# !pip install wget
# !sudo apt-get update && sudo apt-get install sox libsox-fmt-all
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting install
#   Downloading install-1.3.5-py3-none-any.whl (3.2 kB)
# Collecting sox
#   Downloading sox-1.4.1-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from sox) (1.22.4)
# Installing collected packages: sox, install
# Successfully installed install-1.3.5 sox-1.4.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=cd4d0c18bf25191c95c2ca96e4bc8b248da548c4ac12f45b200c55deffd44500
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Hit:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:5 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:7 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:8 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1,581 B]
# Hit:10 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:11 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:12 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,668 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,150 kB]
# Get:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [1,008 kB]
# Fetched 7,168 kB in 1s (5,549 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libao-common libao4 libid3tag0 libmad0 libopencore-amrnb0 libopencore-amrwb0
#   libsox-fmt-alsa libsox-fmt-ao libsox-fmt-base libsox-fmt-mp3 libsox-fmt-oss
#   libsox-fmt-pulse libsox3
# Suggested packages:
#   libaudio2 libsndio6.1
# The following NEW packages will be installed:
#   libao-common libao4 libid3tag0 libmad0 libopencore-amrnb0 libopencore-amrwb0
#   libsox-fmt-all libsox-fmt-alsa libsox-fmt-ao libsox-fmt-base libsox-fmt-mp3
#   libsox-fmt-oss libsox-fmt-pulse libsox3 sox
# 0 upgraded, 15 newly installed, 0 to remove and 25 not upgraded.
# Need to get 694 kB of archives.
# After this operation, 2,319 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libao-common all 1.2.2+20180113-1ubuntu1 [6,644 B]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libao4 amd64 1.2.2+20180113-1ubuntu1 [35.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 libid3tag0 amd64 0.15.1b-14 [31.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmad0 amd64 0.15.1b-10ubuntu1 [63.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrnb0 amd64 0.1.5-1 [94.8 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrwb0 amd64 0.1.5-1 [49.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox3 amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [225 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox-fmt-alsa amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [10.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox-fmt-ao amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [7,492 B]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox-fmt-base amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [31.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox-fmt-mp3 amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [15.9 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox-fmt-oss amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [9,044 B]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox-fmt-pulse amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [7,396 B]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox-fmt-all amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [5,132 B]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 sox amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [102 kB]
# Fetched 694 kB in 0s (4,325 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 15.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libao-common.
# (Reading database ... 122518 files and directories currently installed.)
# Preparing to unpack .../00-libao-common_1.2.2+20180113-1ubuntu1_all.deb ...
# Unpacking libao-common (1.2.2+20180113-1ubuntu1) ...
# Selecting previously unselected package libao4:amd64.
# Preparing to unpack .../01-libao4_1.2.2+20180113-1ubuntu1_amd64.deb ...
# Unpacking libao4:amd64 (1.2.2+20180113-1ubuntu1) ...
# Selecting previously unselected package libid3tag0:amd64.
# Preparing to unpack .../02-libid3tag0_0.15.1b-14_amd64.deb ...
# Unpacking libid3tag0:amd64 (0.15.1b-14) ...
# Selecting previously unselected package libmad0:amd64.
# Preparing to unpack .../03-libmad0_0.15.1b-10ubuntu1_amd64.deb ...
# Unpacking libmad0:amd64 (0.15.1b-10ubuntu1) ...
# Selecting previously unselected package libopencore-amrnb0:amd64.
# Preparing to unpack .../04-libopencore-amrnb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../05-libopencore-amrwb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../06-libsox3_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../07-libsox-fmt-alsa_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Selecting previously unselected package libsox-fmt-ao:amd64.
# Preparing to unpack .../08-libsox-fmt-ao_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking libsox-fmt-ao:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../09-libsox-fmt-base_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Selecting previously unselected package libsox-fmt-mp3:amd64.
# Preparing to unpack .../10-libsox-fmt-mp3_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking libsox-fmt-mp3:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Selecting previously unselected package libsox-fmt-oss:amd64.
# Preparing to unpack .../11-libsox-fmt-oss_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking libsox-fmt-oss:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Selecting previously unselected package libsox-fmt-pulse:amd64.
# Preparing to unpack .../12-libsox-fmt-pulse_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking libsox-fmt-pulse:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Selecting previously unselected package libsox-fmt-all:amd64.
# Preparing to unpack .../13-libsox-fmt-all_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking libsox-fmt-all:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../14-sox_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking sox (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up libsox3:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up libsox-fmt-oss:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up libao-common (1.2.2+20180113-1ubuntu1) ...
# Setting up libid3tag0:amd64 (0.15.1b-14) ...
# Setting up libopencore-amrwb0:amd64 (0.1.5-1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up libao4:amd64 (1.2.2+20180113-1ubuntu1) ...
# Setting up libmad0:amd64 (0.15.1b-10ubuntu1) ...
# Setting up libopencore-amrnb0:amd64 (0.1.5-1) ...
# Setting up libsox-fmt-base:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up libsox-fmt-ao:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up libsox-fmt-mp3:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up libsox-fmt-pulse:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up sox (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up libsox-fmt-all:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for mime-support (3.64ubuntu1) ...

# %%
import sys
import argparse
import csv
import json
import logging
import multiprocessing
import os
import tarfile
from multiprocessing.pool import ThreadPool
from pathlib import Path
from typing import List

import sox
from sox import Transformer
import wget
from tqdm import tqdm

# %%
parser = argparse.ArgumentParser(description='Downloads and processes Mozilla Common Voice dataset.')
parser.add_argument("--data_root", default='CommonVoice_dataset/', type=str, help="Directory to store the dataset.")
parser.add_argument('--manifest_dir', default='./', type=str, help='Output directory for manifests')
parser.add_argument("--num_workers", default=multiprocessing.cpu_count(), type=int, help="Workers to process dataset.")
parser.add_argument('--sample_rate', default=16000, type=int, help='Sample rate')
parser.add_argument('--files_to_process', nargs='+', default=['female_data.tsv', 'male_data.tsv'],
                    type=str, help='list of *.csv file names to process')
parser.add_argument('--version', default='cv-corpus-11.0-2022-09-21',
                    type=str, help='Version of the dataset (obtainable via https://commonvoice.mozilla.org/en/datasets')
parser.add_argument('--language', default='tr',
                    type=str, help='Which language to download.(default english,'
                                   'check https://commonvoice.mozilla.org/en/datasets for more language codes')

# args = parser.parse_args()
args, unknown = parser.parse_known_args()

# %%
# -------- CHANGE VERSION AND LANGUAGE
version = 'cv-corpus-11.0-2022-09-21'
language = 'cv-corpus-11.0-2022-09-21-tr'

COMMON_VOICE_URL = f"https://voice-prod-bundler-ee1969a6ce8178826482b88e843c335139bd3fb4.s3.amazonaws.com/" \
                   "{}/{}.tar.gz".format(version, language)

# %%
def create_manifest(
        data: List[tuple],
        output_name: str,
        manifest_path: str):
    output_file = Path(manifest_path) / output_name
    output_file.parent.mkdir(exist_ok=True, parents=True)
    with output_file.open(mode='w', encoding="utf-8") as f:
        for wav_path, duration, text in tqdm(data, total=len(data)):
            f.write(
                json.dumps({
                    'audio_filepath': wav_path,
                    "duration": duration,
                    'text': text
                },  ensure_ascii=False) + '\n'
            )

def process_files(csv_file, data_root, num_workers):
    """ Read *.csv file description, convert mp3 to wav, process text.
        Save results to data_root.
    Args:
        csv_file: str, path to *.csv file with data description, usually start from 'cv-'
        data_root: str, path to dir to save results; wav/ dir will be created
    """
    wav_dir = os.path.join(data_root, 'wav/')
    os.makedirs(wav_dir, exist_ok=True)
    audio_clips_path = os.path.dirname(csv_file) + '/clips/'

    def process(x):
        file_path, text = x
        file_name = os.path.splitext(os.path.basename(file_path))[0]
        text = text.lower().strip()  
        audio_path = os.path.join(audio_clips_path, file_path)
        output_wav_path = os.path.join(wav_dir, file_name + '.wav')

        tfm = Transformer()
        tfm.rate(samplerate=args.sample_rate)
        tfm.build(
            input_filepath=audio_path,
            output_filepath=output_wav_path
        )
        duration = sox.file_info.duration(output_wav_path)
        return output_wav_path, duration, text

    logging.info('Converting mp3 to wav for {}.'.format(csv_file))
    with open(csv_file, encoding="utf8") as csvfile:
        reader = csv.DictReader(csvfile, delimiter='\t')
        next(reader, None)  # skip the headers
        # data = [(row['path'], row['sentence']) for row in reader]
        data = [(row['path'], row['sentence']) for row in reader if 'path' in row and 'sentence' in row]
        with ThreadPool(num_workers) as pool:
            data = list(tqdm(pool.imap(process, data), total=len(data)))

    print(data)
    return data

# %%
# Install and unzip dataset
data_root = args.data_root
os.makedirs(data_root, exist_ok=True)

target_unpacked_dir = os.path.join(data_root, "CV_unpacked")

if os.path.exists(target_unpacked_dir):
    print('Find existing folder {}'.format(target_unpacked_dir))
else:
    print("Could not find Common Voice, Downloading corpus...")

    filename = wget.download(COMMON_VOICE_URL, data_root)
    target_file = os.path.join(data_root, os.path.basename(filename))

    os.makedirs(target_unpacked_dir, exist_ok=True)
    print("Unpacking corpus to {} ...".format(target_unpacked_dir))
    tar = tarfile.open(target_file, encoding="utf8")
    tar.extractall(target_unpacked_dir)
    tar.close()
    print("Done!")
# Out:
# Could not find Common Voice, Downloading corpus...
# Unpacking corpus to CommonVoice_dataset/CV_unpacked ...
# Done!

# %%
# Select most frequent speakers' recorded audios for male and female speakers

train_tsv = "/content/" + target_unpacked_dir + "/" + version + "/tr/train.tsv"
test_tsv = "/content/" + target_unpacked_dir + "/" + version + "/tr/test.tsv"
validated_tsv = "/content/" + target_unpacked_dir + "/" + version + "/tr/validated.tsv"

tsv_files = [train_tsv, test_tsv, validated_tsv]

from collections import Counter
id_counts = Counter()
id_genders = {}

for tsv_file in tsv_files:
  with open(tsv_file, encoding="utf8") as csvfile:
    reader = csv.DictReader(csvfile, delimiter='\t')
    next(reader, None)
    for row in reader:
        client_id = row['client_id']
        gender = row['gender']
        id_counts[client_id] += 1
        id_genders[client_id] = gender

most_common_ids = id_counts.most_common(5)

for id, count in most_common_ids:
    print(f"Client ID: {id} | Gender: {id_genders[id]} | Count: {count}")
# Out:
# Client ID: ba25f19f22267b1f863cef586f17252a9067bc0ecb3d63dd7626fbce7014a16412dd64d5404d34505c0c90635adbc3cb2d830d77291a4db194e5abad91160957 | Gender: female | Count: 17252
# Client ID: 6cf4dea5df1dfe5dc5d7bacdb6da105b9e48e01fd0f069dbaf0ad906a7c5d78032194a3a9384e8589b93c58a04a12f676669f4c4501e52cee652f331b72b9205 | Gender: female | Count: 17194
# Client ID: c3c204ffaebfc46c0265773376f9288a372694aa79f97afe224828033c28d6d2a90919aaf769bf14105cb4033650e10275760afe250490782eae15c1d1518799 | Gender: male | Count: 6349
# Client ID: 60cee2235d7ec4cdeb89d601b8c373955b303c712ec729ed0affdabda8819908f51cefa990163d2bc4ac04c93e6dac2909cca67829211df4a2a17af2507dd50a | Gender:  | Count: 6291
# Client ID: ca179eb54e4e584d30587ba3c6c1d4de7d9082d649113d481d308f3e7d858e0a1df21d9591f9c613928b1e122aa7f54535d0f0e0c1380d87d8017844e6e73ea2 | Gender: male | Count: 4837

# %%
female_rank = input("Choose the ID number rank for the female voice dataset:")
male_rank = input("Choose the ID number rank for the male voice dataset:")
print(f"Selected female voice ID: {id_counts.most_common(int(female_rank))[int(female_rank)-1][0]}")
print(f"Selected male voice ID:   {id_counts.most_common(int(male_rank))[int(male_rank)-1][0]}")
# Out:
# Choose the ID number rank for the female voice dataset:1
# Choose the ID number rank for the male voice dataset:3
# Selected female voice ID: ba25f19f22267b1f863cef586f17252a9067bc0ecb3d63dd7626fbce7014a16412dd64d5404d34505c0c90635adbc3cb2d830d77291a4db194e5abad91160957
# Selected male voice ID:   c3c204ffaebfc46c0265773376f9288a372694aa79f97afe224828033c28d6d2a90919aaf769bf14105cb4033650e10275760afe250490782eae15c1d1518799

# %%
# Create tsv files for new datasets
female_data = "/content/" + target_unpacked_dir + "/" + version + "/tr/female_data.tsv"
male_data = "/content/" + target_unpacked_dir + "/" + version + "/tr/male_data.tsv"

for tsv_file in tsv_files:
  with open(tsv_file, encoding="utf8") as csvfile, \
       open(female_data, mode='w', encoding='utf-8', newline='') as female_file, \
       open(male_data, mode='w', encoding='utf-8', newline='') as male_file:

      reader = csv.DictReader(csvfile, delimiter='\t')
      next(reader, None)

      fwriter = csv.DictWriter(female_file, fieldnames=reader.fieldnames, delimiter='\t')
      mwriter = csv.DictWriter(male_file, fieldnames=reader.fieldnames, delimiter='\t')
      fwriter.writeheader()
      mwriter.writeheader()
      csvfile.seek(0)
      next(csvfile, None)

      for row in reader:
        if (row['client_id'] == id_counts.most_common(int(female_rank))[int(female_rank)-1][0]):
          fwriter.writerow(row)
        if row['client_id'] == id_counts.most_common(int(male_rank))[int(male_rank)-1][0]:
          mwriter.writerow(row)

print(f"female_data.tsv and male_data.tsv files are created in /content/{target_unpacked_dir}/{version}/tr")
# Out:
# female_data.tsv and male_data.tsv files are created in /content/CommonVoice_dataset/CV_unpacked/cv-corpus-11.0-2022-09-21/tr

# %%
# !rm -r /content/CommonVoice_dataset/female_data

# %%
folder_path = os.path.join("/content/"+ target_unpacked_dir, args.version + f'/{args.language}/')

for csv_file in args.files_to_process:
    data = process_files(
        csv_file=os.path.join(folder_path, csv_file),
        data_root=os.path.join(data_root, os.path.splitext(csv_file)[0]),
        num_workers=args.num_workers
    )
    logging.info('Creating manifests...')
    create_manifest(
        data=data,
        output_name=f'commonvoice_{os.path.splitext(csv_file)[0]}_manifest.jsonl',
        manifest_path=args.manifest_dir,
    )
# Out:
# 100%|██████████| 9960/9960 [02:51<00:00, 57.97it/s]
# [('CommonVoice_dataset/female_data/wav/common_voice_tr_29451803.wav', 4.752, 'nasıl söyleyeceğimi bilmiyorum.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451804.wav', 2.412, 'futbol mu?'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451805.wav', 3.564, 'i̇yiyim anne.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451806.wav', 3.924, 'onu rahat bırakın!'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451817.wav', 3.492, 'o benim patronum.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451818.wav', 3.42, 'bunu hallederiz.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451820.wav', 3.204, 'sana sahibim.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451822.wav', 2.772, 'şişko!'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451825.wav', 2.952, 'evet, ama ben…'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451852.wav', 4.032, 'sormak zorundaydım.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451853.wav', 4.68, 'yalnız mıyız?'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451854.wav', 3.42, 'hiç utanmıyor musun?'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451855.wav', 3.204, 'bu çok salakça.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451856.wav', 2.664, 'avukatım nerede?'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451883.wav', 3.924, 'i̇yi olduğunuzdan emin misiniz?'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451885.wav', 2.7, 'reddetti.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451886.wav', 3.564, 'bunu düzelteceğim.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451888.wav', 3.024, 'getir!'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451889.wav', 3.312, 'anladınız mı beni?'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451956.wav', 4.32, 'şey, o…'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451960.wav', 3.924, 'kardeşin öldü.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451963.wav', 3.42, 'şöyle yapacağız…'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451964.wav', 3.564, 'yer değiştirelim.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451965.wav', 3.204, 'delirmiş!'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451986.wav', 3.492, 'uzanın…'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451987.wav', 3.42, 'i̇lgilenir misin?'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451988.wav', 3.744, 'bunu bilmelisin.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451989.wav', 3.204, 'bu onların sorunu.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29451990.wav', 2.844, 'başardık mı?'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29452021.wav', 3.492, 'tek başımayım.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29452022.wav', 3.492, 'devam edin lütfen.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29452023.wav', 3.924, 'başka sorum yok, sayın yargıç.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29452024.wav', 3.492, 'başka çarem yoktu.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29452026.wav', 2.772, 'toparlan!'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29452061.wav', 3.384, 'bunu tanıyor musun?'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29452062.wav', 3.672, 'kimseden…'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29452063.wav', 3.312, 'burda ne işin var?'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29452064.wav', 3.96, 'neden değil?'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29452065.wav', 3.024, 'bir yere gittiğim yok.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29452099.wav', 3.6, 'peşinden gideceğim.'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29452100.wav', 3.384, 'uyansana!'), ('CommonVoice_dataset/female_data/wav/common_voice_tr_29 ...
# 100%|██████████| 9960/9960 [00:00<00:00, 92701.47it/s]
# 100%|██████████| 4999/4999 [01:25<00:00, 58.21it/s]
# [('CommonVoice_dataset/male_data/wav/common_voice_tr_26531087.wav', 1.26, 'o iyi.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531093.wav', 1.512, 'tanrıya şükür!'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531100.wav', 1.908, 'karaltı yaklaştı…'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531114.wav', 3.384, 'eh, aç da durulmuyor, allah taksiratımızı affetsin!'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531130.wav', 3.96, 'ne yapacaksın?'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531137.wav', 1.332, 'beklerim.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531158.wav', 1.44, 'mümkün değil.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531165.wav', 1.728, 'başardın.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531175.wav', 1.692, 'burada bir şey yok.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531185.wav', 3.42, "ortadan kaybolanlar viktor'la suzan'dı…"), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531188.wav', 1.26, 'yarın mı?'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531192.wav', 3.204, 'bu mücadelede ikimiz de bütün zekamızı kullanıyorduk.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531193.wav', 2.7, 'gece, hafif yağmur çiseliyordu.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531195.wav', 1.44, 'teğmen.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531200.wav', 4.284, 'on beş dakika istirahatten sonra feci dramlar, kahkahalı komediler başlayacaktı…'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531206.wav', 1.908, 'ne var orada?'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531208.wav', 1.512, 'çok iyiydi.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531209.wav', 1.404, 'dışarı çıkın!'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531211.wav', 3.132, 'fakat üzerinde yürüdüğün yola bu kadar inanıyor musun?'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531216.wav', 1.656, 'seninle konuşmak istiyor.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531217.wav', 1.584, 'ne kadar sürecek?'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531218.wav', 2.232, 'halbuki bir şey de konuşmuş sayılmazlardı.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531223.wav', 2.556, 'çünkü birbirlerine başkaca kinleri yoktu.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531225.wav', 2.268, 'deminki genç kız yine aklıma geldi…'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531226.wav', 1.908, 'çay taşmış diyorlardı…'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531230.wav', 4.284, "kendi kendime bir daha: 'yandın garip halil efe yandın!' dedim."), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531234.wav', 1.296, 'olay nedir?'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531240.wav', 1.296, 'olurum.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531241.wav', 1.476, 'zavallılar!'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531245.wav', 4.896, 'memleketten gelip şehirde yerleşmiş, oldukça hali vakti yerinde bir dayısı vardı.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531254.wav', 4.104, 'masanın üstünde duran elime yapıştı: "artık dayanamayacağım…" dedi.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531256.wav', 3.24, 'bir gün o ve onun gibiler hakim olursa…'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531258.wav', 5.364, 've karşımdaki kandilin arkasında, ona benzeyen sayısı bellisiz kandiller sıralandığını gördüm.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531259.wav', 1.332, 'ya şimdi?'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531267.wav', 1.008, 'hadi, hadi.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531271.wav', 2.052, 'gitgide herkes cıvıttı.'), ('CommonVoice_dataset/male_data/wav/common_voice_tr_26531272.wav', 1.224, 'bağırdım…'), ('CommonVoice_da ...
# 100%|██████████| 4999/4999 [00:00<00:00, 71643.24it/s]

# %%
def get_duration(manifest):
  total_duration = 0
  with open(manifest, "r", encoding="utf-8") as fin:
    for line in fin:
      original_file_json = json.loads(line)
      total_duration += original_file_json["duration"]
  return total_duration

f_duration = get_duration("/content/commonvoice_female_data_manifest.jsonl")
m_duration = get_duration("/content/commonvoice_male_data_manifest.jsonl")
print(f"Female voice dataset total duration:{round(f_duration/3600, 2)} hours")
print(f"Male voice  dataset total duration:{round(m_duration/3600, 2)} hours")
# Out:
# Female voice dataset total duration:9.35 hours
# Male voice  dataset total duration:3.09 hours

# %%
import os 
folder_path = "/content/CommonVoice_dataset/male_data/wav/"

files = os.listdir(folder_path)
wav_files = [file for file in files if file.endswith(".wav")]
len(wav_files)
# Out:
# 4999

# %%
# !zip -r /content/CommonVoice_dataset/female_data.zip /content/CommonVoice_dataset/female_data
# !zip -r /content/CommonVoice_dataset/male_data.zip /content/CommonVoice_dataset/male_data

# %%
from google.colab import files
# files.download('/content/CommonVoice_dataset/female_data.zip')
# files.download('/content/CommonVoice_dataset/male_data.zip')
